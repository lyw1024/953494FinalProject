# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv("/Users/almostloverv/Desktop/953494FinalProject/league-of-legends-ranked-games/challenger.csv")
dataset.drop(['vilemaw_kills_team_1', 'vilemaw_kills_team_2'], axis=1, inplace=True)
dataset.head(10)
# Out:
#    win  first_blood  first_tower  first_inhibitor  first_baron  first_dragon  \
# 0    2            2            2                2            0             2
# 1    2            2            2                0            0             2
# 2    2            2            0                2            2             1
# 3    1            1            0                1            1             1
# 4    2            2            0                2            2             2
# 5    2            1            0                2            1             2
# 6    1            1            2                2            1             1
# 7    2            1            2                2            2             2
# 8    2            2            2                2            0             1
# 9    2            2            2                0            2             2
#
#    first_rift_herald  tower_kills_team_1  inhibitor_kills_team_1  \
# ...

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
g = sns.distplot(dataset["win"])
